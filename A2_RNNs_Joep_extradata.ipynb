# %% [markdown]
# # Introduction to Deep Learning, Assignment 2, Task 2

# %% [markdown]
# # Function definitions for creating the datasets
#
# First we need to create our datasets that are going to be used for training our models.
#
# In order to create image queries of simple arithmetic operations such as '15+13' or '42-10' we need to create images of '+' and '-' signs using ***open-cv*** library. We will use these operand signs together with the MNIST dataset to represent the digits.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import numpy as np
import tensorflow as tf
import random
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Dense, RNN, LSTM, Flatten, TimeDistributed, LSTMCell
from tensorflow.keras.layers import RepeatVector, Conv2D, SimpleRNN, GRU, Reshape, ConvLSTM2D, Conv2DTranspose

# %%
from scipy.ndimage import rotate


# Create plus/minus operand signs
def generate_images(number_of_images=50, sign='-'):
    blank_images = np.zeros([number_of_images, 28, 28])  # Dimensionality matches the size of MNIST images (28x28)
    x = np.random.randint(12, 16, (number_of_images, 2)) # Randomized x coordinates
    y1 = np.random.randint(6, 10, number_of_images)       # Randomized y coordinates
    y2 = np.random.randint(18, 22, number_of_images)     # -||-

    for i in range(number_of_images): # Generate n different images
        cv2.line(blank_images[i], (y1[i], x[i,0]), (y2[i], x[i, 1]), (255,0,0), 2, cv2.LINE_AA)     # Draw lines with randomized coordinates
        if sign == '+':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA) # Draw lines with randomized coordinates

    return blank_images

def show_generated(images, n=5):
    plt.figure(figsize=(2, 2))
    for i in range(n**2):
        plt.subplot(n, n, i+1)
        plt.axis('off')
        plt.imshow(images[i])
    plt.show()

# %%
def create_data(highest_integer, num_addends=2, operands=['+', '-']):
    """
    Creates the following data for all pairs of integers up to [1:highest integer][+/-][1:highest_integer]:

    @return:
    X_text: '51+21' -> text query of an arithmetic operation (5)
    X_img : Stack of MNIST images corresponding to the query (5 x 28 x 28) -> sequence of 5 images of size 28x28
    y_text: '72' -> answer of the arithmetic text query
    y_img :  Stack of MNIST images corresponding to the answer (3 x 28 x 28)

    Images for digits are picked randomly from the whole MNIST dataset.
    """

    num_indices = [np.where(MNIST_labels==x) for x in range(10)]
    num_data = [MNIST_data[inds] for inds in num_indices]
    image_mapping = dict(zip(unique_characters[:10], num_data))
    image_mapping['-'] = generate_images()
    image_mapping['+'] = generate_images(sign='+')
    image_mapping['*'] = generate_images(sign='*')
    image_mapping[' '] = np.zeros([1, 28, 28])

    X_text, X_img, y_text, y_img = [], [], [], []

    for i in range(highest_integer + 1):      # First addend
        for j in range(highest_integer + 1):  # Second addend
            for sign in operands: # Create all possible combinations of operands
                query_string = to_padded_chars(str(i) + sign + str(j), max_len=max_query_length, pad_right=True)
                query_image = []
                for n, char in enumerate(query_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    query_image.append(image_set[index].squeeze())

                result = eval(query_string)
                result_string = to_padded_chars(result, max_len=max_answer_length, pad_right=True)
                result_image = []
                for n, char in enumerate(result_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    result_image.append(image_set[index].squeeze())

                X_text.append(query_string)
                X_img.append(np.stack(query_image))
                y_text.append(result_string)
                y_img.append(np.stack(result_image))

    return np.stack(X_text), np.stack(X_img)/255., np.stack(y_text), np.stack(y_img)/255.

def to_padded_chars(integer, max_len=3, pad_right=False):
    """
    Returns a string of len()=max_len, containing the integer padded with ' ' on either right or left side
    """
    length = len(str(integer))
    padding = (max_len - length) * ' '
    if pad_right:
        return str(integer) + padding
    else:
        return padding + str(integer)

# %% [markdown]
# # Creating our data
#
# The dataset consists of 20000 samples that (additions and subtractions between all 2-digit integers) and they have two kinds of inputs and label modalities:
#
#   **X_text**: strings containing queries of length 5: ['  1+1  ', '11-18', ...]
#
#   **X_image**: a stack of images representing a single query, dimensions: [5, 28, 28]
#
#   **y_text**: strings containing answers of length 3: ['  2', '156']
#
#   **y_image**: a stack of images that represents the answer to a query, dimensions: [3, 28, 28]

# %%
# Illustrate the generated query/answer pairs

unique_characters = '0123456789+- '       # All unique characters that are used in the queries (13 in total: digits 0-9, 2 operands [+, -], and a space character ' '.)
highest_integer = 99                      # Highest value of integers contained in the queries

max_int_length = len(str(highest_integer))# Maximum number of characters in an integer
max_query_length = max_int_length * 2 + 1 # Maximum length of the query string (consists of two integers and an operand [e.g. '22+10'])
max_answer_length = 3    # Maximum length of the answer string (the longest resulting query string is ' 1-99'='-98')

# Create the data (might take around a minute)
(MNIST_data, MNIST_labels), _ = tf.keras.datasets.mnist.load_data()
X_text, X_img, y_text, y_img = create_data(highest_integer)
print(X_text.shape, X_img.shape, y_text.shape, y_img.shape)

def add_random_padding(y_text, length_new):
    y_text_out = list(np.zeros(len(y_text)))
    for i in range(len(y_text)):
        result = y_text[i]
        digits = len(result)
        cuts = [0] + sorted(random.sample(range(length_new-digits), digits))
        string = '' 
        for cut in range(digits):
            pad = cuts[cut+1] - cuts[cut]
            string += int(pad)*' '+ result[cut]
        pad = length_new-digits - cuts[-1]
        string+= pad*' '
        y_text_out[i] = string
    
    return np.array(y_text_out)

max_answer_length_new = 7


y_text2 = add_random_padding(y_text, max_answer_length_new)
X_img2 = np.copy(X_img)
for i in range(4):
    y_text2 = np.append(y_text2, add_random_padding(y_text, max_answer_length_new))
    X_img2 = np.append(X_img2, X_img, axis = 0)
print(X_img2.shape, y_text2.shape)
print(y_text2[0:10])

max_answer_length = max_answer_length_new
# Out:
# (20000,) (20000, 5, 28, 28) (20000,) (20000, 3, 28, 28)
# (100000, 5, 28, 28) (100000,)
# [' 0     ' ' 0     ' ' 1     ' '-  1   ' ' 2     ' '-  2   ' '3      '
#  '-  3   ' '4      ' '-  4   ']

# %% [markdown]
# # My own helper functions
#
# In the models below teacher forcing is used. For this the vocabulary will need a start and end token. Subsequently the one-hot encoding and decoding functions need to be altered to include these.

# %%
# Teacher forcing preparation
vocabulary_tf = list(unique_characters)+['<start>','<end>',' '] 
indices = {char:i for i, char in enumerate(vocabulary_tf)}
reverse_indices={i:char for i,char in enumerate(vocabulary_tf)}

# One-hot encoding
def encode_labels_tf(labels, vocab=vocabulary_tf, indices_map=indices):
  n = len(labels)
  length = len(labels[0])+2 # for start of sequence <start> and end of sequence <end> tokens.
  one_hot = np.zeros([n, length, len(vocab)])
  for i, label in enumerate(labels):
    full_label = ['<start>'] + list(label) + ['<end>']
    m = np.zeros([length, len(vocab)])
    for j, char in enumerate(full_label):
       m[j, indices_map[char]] = 1
    one_hot[i] = m

  return one_hot

# One-hot decoding
def decode_labels_tf(labels, vocabulary=vocabulary_tf, indices_map = reverse_indices):
    pred = np.argmax(labels, axis=2)
    predicted = [''.join([indices_map[i] for i in j]) for j in pred]

    return predicted

#X_text_onehot = encode_labels_tf(X_text)
y_text_onehot = encode_labels_tf(y_text2)

print(y_text_onehot.shape)
# Out:
# (100000, 9, 16)

# %%
# Teacher forcing preparation
vocabulary_tf = list(unique_characters)+['<start>','<end>', ' '] 

indices = {char:i for i, char in enumerate(vocabulary_tf)}
reverse_indices={i:char for i,char in enumerate(vocabulary_tf)}


# One-hot encoding
def encode_labels_tf(labels, vocabulary=vocabulary_tf, indices_map=indices):
  n = len(labels)
  length = len(labels[0])+2 # for start of sequence <start> and end of sequence <end> tokens.

  one_hot = np.zeros([n, length, len(vocabulary)])
  for i, label in enumerate(labels):
    full_label = ['<start>'] + list(label) + ['<end>']
    m = np.zeros([length, len(vocabulary)])
    for j, char in enumerate(full_label):
       if char != ' ':
        m[j, indices_map[char]] = 1
    one_hot[i] = m

  return one_hot

# One-hot decoding
def decode_labels_tf(labels, vocabulary=vocabulary_tf, indices_map = reverse_indices):
    pred = np.argmax(labels, axis=2)
    predicted = [''.join([indices_map[i] for i in j]) for j in pred]

    return predicted

X_text_onehot = encode_labels_tf(X_text)
y_text_onehot = encode_labels_tf(y_text2)

print(X_img2.shape, y_text_onehot.shape)
# Out:
# (100000, 5, 28, 28) (100000, 9, 16)

# %% [markdown]
# # Model with attention

# %%
size=0.1

X_train, X_test, y_train, y_test = train_test_split(
    X_img2, y_text_onehot, random_state=42, test_size=size
)

X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, random_state=42, test_size=size/(1-size)
)

y_train_in = y_train[:, :-1, :]
y_train_target = y_train[:, 1:, :]

y_val_in = y_val[:, :-1, :]
y_val_target = y_val[:, 1:, :]

y_test_in = y_test[:, :-1, :]
y_test_target = y_test[:, 1:, :]

# %%
# Your code is: damn code

from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D, LSTM, TimeDistributed, Dropout, Input, Add, LayerNormalization, Attention, Concatenate
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import L2, L1L2


# First we create a build-encoder function
def build_image2text_encoder(dropout, RLstrength, max_size=512):
    
    # Initialize an encoder
    X_in = Input(shape = (5,28,28,1)) # 5 times a grayscale image


    # Build encoder layers
    ## Block 1
    B1 = TimeDistributed(Conv2D(32, (3,3), padding = "same"))(X_in)
    B1 = TimeDistributed(BatchNormalization())(B1)
    B1 = TimeDistributed(Activation('relu'))(B1)
    B1 = TimeDistributed(Dropout(dropout))(B1)
    B1_final = TimeDistributed(MaxPooling2D())(B1)


    ## Initialize the residual connection
    residual = Activation('linear', name = "residual_branch")(B1_final)
    residual2= TimeDistributed(Conv2D(64, (1,1)))(residual)
    
    ## Block 2
    B2 = TimeDistributed(Conv2D(64, (3,3), padding = "same"))(B1_final)
    B2 = TimeDistributed(BatchNormalization())(B2)
    B2 = TimeDistributed(Activation('relu'))(B2)
    B2_final = TimeDistributed(Dropout(dropout))(B2)

    ## Connect residual connection to output of two Conv2D blocks
    combined = Add()([B2_final, residual2])
    combined = TimeDistributed(Activation('relu'))(combined)

    ## Final pooling before the ConvLSTM2D layer
    final_pooling = TimeDistributed(MaxPooling2D(name='final_pooling'))(combined)


    ## Recurrent convolutional layers
    output, hidden, cell = ConvLSTM2D(
            filters=128, 
            kernel_size=(3,3), 
            padding='same',
            return_sequences=True, 
            use_bias=True, 
            return_state=True, 
            name='ConvLSTM', 
            dropout=dropout, #dropout
            recurrent_dropout=dropout, #dropout
            recurrent_regularizer = L2(RLstrength))(final_pooling) #L2(RLstrength)

    encoder = tf.keras.Model(inputs=X_in, outputs=[output, hidden, cell], name = "encoder_model")
    return encoder





# Here we build the full model
def build_image2text(dropout = 0.3, max_size=512, learning_rate = 2.5e-4, max_answer_length_tf=8,RLstrength=1.0e-4):


    # Define input layer of full model
    X_in = Input(shape = (5,28,28,1), name = 'sequence')
    Y_in = Input(shape=(max_answer_length_tf, 16)) #max_answer_length_tf, len(vocabulary_tf)


    # Encoder step
    encoder = build_image2text_encoder(dropout,RLstrength)
    output, hidden, cell = encoder(X_in)


    # Bridge step
    ## We take the output hidden and cell state of the encoder so that we may use teacher forcing.
    h_flattened = Flatten(name='h_flattened')(hidden)
    h_initial = Dense(max_size, activation = 'relu',kernel_regularizer=L2(RLstrength), name='h0')(h_flattened)

    c_flattened = Flatten(name='c_flattened')(cell)
    c_initial = Dense(max_size, activation = 'relu',kernel_regularizer=L2(RLstrength),name='c0')(c_flattened)

    ini_state = [h_initial, c_initial]

    # Decoder step
    ## We initialize the decoder using teacher forcing

    lstm = LSTM(
        max_size, 
        return_sequences = True, 
        return_state=True, 
        dropout = dropout, 
        recurrent_dropout = dropout, 
        name='decoder_lstm',
        kernel_regularizer = L2(RLstrength/4),
        recurrent_regularizer = L2(RLstrength/4)
        )(Y_in, initial_state = ini_state) #
    
    dense = TimeDistributed(Dense(len(vocabulary_tf), activation='softmax'), name = 'decoder_dense')

    query, _, _ = lstm

    key_flatten = TimeDistributed(Flatten(), name='key_flatten')(output)
    key = TimeDistributed(Dense(max_size, kernel_regularizer = L2(RLstrength/2)), name = 'key_decoder')(key_flatten)
    attention_block = Attention(name='attention_block')([query, key])

    combined = Concatenate(axis=-1, name = 'concat_q_A')([query, attention_block])
    combined = Dense(max_size, name = 'combined_dense', kernel_regularizer = L1L2(l1 = 5.0e-5, l2=RLstrength/2))(combined)

    residual = TimeDistributed(Dense(
        max_size, 
        use_bias=False, 
        kernel_regularizer = L2(RLstrength/2)
        ), 
        name = 'decoder_res_dense'
        )(Y_in)

    final = Add(name= 'decoder_with_residual')([combined, residual])
    final = LayerNormalization(axis=-1, name='decoder_layer_norm')(final)
    y_out = dense(final)


    # Full model step
    full = tf.keras.Model(inputs=[X_in, Y_in], outputs = y_out)
    full.compile(
        loss='categorical_crossentropy', optimizer=Adam(learning_rate=learning_rate), metrics=['categorical_accuracy']
    )

    full.summary(expand_nested=True)
    return full

# %%
y_text_onehot.shape
# Out:
# (100000, 9, 15)

# %% [markdown]
# ##### Model initialization and compile

# %%
dropout=0.55
learning_rate=4.0e-4
RLstrength=8.0e-4
max_size=128

image2text = build_image2text(dropout=dropout, learning_rate=learning_rate, RLstrength=RLstrength, max_size=max_size)



early_stopper = tf.keras.callbacks.EarlyStopping(
    monitor = 'val_loss',
    patience=7,
    restore_best_weights=True
)

lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=4,
    min_lr=1e-6,
    verbose=1
)

history = image2text.fit(x=[X_train, y_train_in], y=y_train_target, 
               epochs = 40,
               batch_size = 64,
               validation_data = ([X_val, y_val_in], y_val_target),
               callbacks=[lr_scheduler, early_stopper])
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ sequence            │ (None, 5, 28, 28, │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_model       │ [(None, 5, 7, 7,  │    906,560 │ sequence[0][0]    │
# │ (Functional)        │ 128), (None, 7,   │            │                   │
# │                     │ 7, 128), (None,   │            │                   │
# │                     │ 7, 7, 128)]       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │    └ input_layer_12 │ (None, 5, 28, 28, │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │    └                │ (None, 5, 28, 28, │        320 │ -                 │
# │ time_distributed_61 │ 32)               │            │                   │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │    └                │ (None, 5, 28, 28, │        128 │ -                 │
# │ time_distributed_62 │ 32)               │            │                   │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │    └                │ (None, 5, 28, 28, │          0 │ -                 │
# │ time_distributed_63 │ 32)               │            │                   │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │    └                │ (None, 5, 28, 28, │          0 │ -                 │
# │ time_distributed_64 │ 32)               │            │                   │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │    └                │ (None, 5, 14, 14, │          0 │ -                 │
# │ time_distributed_65 │ 32)               │            │                   │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │    └                │ (None, 5, 14, 14, │     18,496 │ -                 │
# │ time_distributed_67 │ 64)               │            │                   │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │    └                │ (None, 5, 14, 14, │        256 │ -                 │
# │ time_distributed_68 │ 64)               │            │                   │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │    └                │ (None, 5, 14, 14, │          0 │ -                 │
# │ time_distributed_69 │ 64)               │            │                   │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │    └                │ (None, 5, 14, 14, │          0 │ -                 │
# │ residual_branch     │ 32)               │            │                   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │    └                │ (None, 5, 14, 14, │          0 │ -                 │
# │ time_distributed_70 │ 64)               │            │                   │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │    └                │ (None, 5, 14, 14, │      2,112 │ -                 │
# │ time_distributed_66 │ 64)               │            │                   │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │    └ add_5 (Add)    │ (None, 5, 14, 14, │          0 │ -                 │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │    └                │ (None, 5, 14, 14, │          0 │ -                 │
# │ time_distributed_71 │ 64)               │            │                   │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │    └                │ (None, 5, 7, 7,   │          0 │ -                 │
# │ time_distributed_72 │ 64)               │            │                   │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │    └ ConvLSTM       │ [(None, 5, 7, 7,  │    885,248 │ -                 │
# │ (ConvLSTM2D)        │ 128), (None, 7,   │            │                   │
# │                     │ 7, 128), (None,   │            │                   │
# │                     │ 7, 7, 128)]       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ h_flattened         │ (None, 6272)      │          0 │ encoder_model[0]… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c_flattened         │ (None, 6272)      │          0 │ encoder_model[0]… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_11      │ (None, 8, 16)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ h0 (Dense)          │ (None, 128)       │    802,944 │ h_flattened[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c0 (Dense)          │ (None, 128)       │    802,944 │ c_flattened[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ key_flatten         │ (None, 5, 6272)   │          0 │ encoder_model[0]… │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_lstm (LSTM) │ [(None, 8, 128),  │     74,240 │ input_layer_11[0… │
# │                     │ (None, 128),      │            │ h0[0][0],         │
# │                     │ (None, 128)]      │            │ c0[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ key_decoder         │ (None, 5, 128)    │    802,944 │ key_flatten[0][0] │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_block     │ (None, 8, 128)    │          0 │ decoder_lstm[0][… │
# │ (Attention)         │                   │            │ key_decoder[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concat_q_A          │ (None, 8, 256)    │          0 │ decoder_lstm[0][… │
# │ (Concatenate)       │                   │            │ attention_block[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ combined_dense      │ (None, 8, 128)    │     32,896 │ concat_q_A[0][0]  │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_res_dense   │ (None, 8, 128)    │      2,048 │ input_layer_11[0… │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_with_resid… │ (None, 8, 128)    │          0 │ combined_dense[0… │
# │ (Add)               │                   │            │ decoder_res_dens… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_layer_norm  │ (None, 8, 128)    │        256 │ decoder_with_res… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_dense       │ (None, 8, 16)     │      2,064 │ decoder_layer_no… │
# │ (TimeDistributed)   │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,426,896 (13.07 MB)
#  Trainable params: 3,426,704 (13.07 MB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/40
# E0000 00:00:1765473947.067155 2088353 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/functional_6_1/encoder_model_1/time_distributed_64_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 52ms/step - categorical_accuracy: 0.2467 - loss: 0.8885 - val_categorical_accuracy: 0.2108 - val_loss: 0.7023 - learning_rate: 4.0000e-04
# Epoch 2/40
#   53/1250 ━━━━━━━━━━━━━━━━━━━━ 1:00 51ms/step - categorical_accuracy: 0.2376 - loss: 0.6977
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 24
#      10 early_stopper = tf.keras.callbacks.EarlyStopping(
#      11     monitor = 'val_loss',
#      12     patience=7,
#      13     restore_best_weights=True
#      14 )
#      16 lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
#      17     monitor='val_loss',
#      18     factor=0.5,
#    (...)     21     verbose=1
#      22 )
# ---> 24 history = image2text.fit(x=[X_train, y_train_in], y=y_train_target,
#      25                epochs = 40,
#      26                batch_size = 64,
#      27                validation_data = ([X_val, y_val_in], y_val_target),
#      28                callbacks=[lr_scheduler, early_stopper])
#
# File ~/.conda/envs/IDL/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.conda/envs/IDL/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:399, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397 for begin_step, end_step, iterator in epoch_iterator:
#     398     callbacks.on_train_batch_begin(begin_step)
# --> 399     logs = self.train_function(iterator)
#     400     callbacks.on_train_batch_end(end_step, logs)
#     401     if self.stop_training:
#
# File ~/.conda/envs/IDL/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:242, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     238 if isinstance(
#     239     iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240 ):
#     241     opt_outputs = multi_step_on_iterator(iterator)
# --> 242     if not opt_outputs.has_value():
#     243         raise StopIteration
#     244     return opt_outputs.get_value()
#
# File ~/.conda/envs/IDL/lib/python3.12/site-packages/tensorflow/python/data/ops/optional_ops.py:176, in _OptionalImpl.has_value(self, name)
#     174 def has_value(self, name=None):
#     175   with ops.colocate_with(self._variant_tensor):
# --> 176     return gen_optional_ops.optional_has_value(
#     177         self._variant_tensor, name=name
#     178     )
#
# File ~/.conda/envs/IDL/lib/python3.12/site-packages/tensorflow/python/ops/gen_optional_ops.py:172, in optional_has_value(optional, name)
#     170 if tld.is_eager:
#     171   try:
# --> 172     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     173       _ctx, "OptionalHasValue", name, optional)
#     174     return _result
#     175   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
print(history.history)

#rint(f"The best val_loss was at epoch {best_epoch}. This had accuracy = {accuracy[best_epoch]}, loss = {loss[best_epoch]}, val_accuracy = {val_accuracy[best_epoch]} and val_loss = {val_loss[best_epoch]}")
# Out:
# {'categorical_accuracy': [0.4796549677848816, 0.5481592416763306, 0.5525345206260681, 0.5588161945343018, 0.5643008947372437, 0.566238522529602, 0.5681761503219604, 0.5719888806343079, 0.5782548785209656, 0.5794581174850464, 0.5843490362167358, 0.5883648991584778, 0.5938965082168579, 0.5998656153678894, 0.605866014957428, 0.6152884364128113, 0.6217263340950012, 0.6292111873626709, 0.6378679871559143, 0.6451027989387512, 0.6527751684188843, 0.6591662168502808, 0.6687917709350586, 0.6789955496788025, 0.6879023909568787, 0.697324812412262, 0.7106537818908691, 0.725420355796814, 0.7374523282051086, 0.7532345652580261, 0.7622820138931274, 0.7712825536727905, 0.7818769812583923, 0.7923464179039001, 0.800518810749054, 0.8072848320007324, 0.8144258856773376, 0.8210982084274292, 0.8267860412597656, 0.8326457738876343, 0.8419119715690613, 0.8428651690483093, 0.8483498692512512, 0.8530689477920532, 0.8582255244255066, 0.8607569336891174, 0.8649915456771851, 0.868085503578186, 0.8713825941085815, 0.8749140501022339, 0.8772579431533813, 0.8809769153594971, 0.8848053216934204, 0.8869773149490356, 0.8895243406295776, 0.8908056616783142, 0.8916338682174683, 0.8980717658996582, 0.8976342082023621, 0.9000874757766724, 0.9028533101081848, 0.9041502475738525, 0.905447244644165, 0.9090099334716797, 0.9091036915779114, 0.9107756614685059, 0.9136664867401123, 0.9135571122169495, 0.9143227934837341, 0.9188386797904968, 0.9374336004257202, 0.9418557286262512, 0.9428245425224304, 0.9447309374809265, 0.9454340934753418, 0.9463247656822205, 0.9480123519897461, 0.9487155675888062, 0.9488874077796936, 0.9489187002182007, 0.9504187703132629, 0.9507781863212585, 0.9510438442230225, 0.9506531953811646, 0.9536689519882202], 'loss': [2.733577013015747, 2.0667190551757812, 1.8536370992660522, 1.7145920991897583, 1.6184163093566895, 1.5410916805267334, 1.4811168909072876, 1.430555820465088, 1.3818304538726807, 1.347269892692566, 1.3130223751068115, 1.2860748767852783, 1.2587286233901978, 1.2345623970031738, 1.2151461839675903, 1.1891703605651855, 1.1590577363967896, 1.1314181089401245, 1.1063816547393799, 1.087037205696106, 1.0615922212600708, 1.045037031173706, 1.0181875228881836, 0.994857668876648, 0.9754443168640137, 0.9547656774520874, 0.9264780282974243, 0.8925864100456238, 0.8690129518508911, 0.834098756313324, 0.8131906986236572, 0.7930471301078796, 0.7692328095436096, 0.7512512803077698, 0.7284561991691589, 0.713812530040741, 0.6952235698699951, 0.678715169429779, 0.6644882559776306, 0.652423083782196, 0.6324706077575684, 0.6284542083740234, 0.6132494807243347, 0.5999468564987183, 0.592844545841217, 0.5838340520858765, 0.5702346563339233, 0.5685009956359863, 0.5607690215110779, 0.5495105385780334, 0.5446152091026306, 0.5364747047424316, 0.5265834927558899, 0.5203284621238708, 0.5165457129478455, 0.5128458142280579, 0.5112172365188599, 0.49286210536956787, 0.4932360053062439, 0.4896427094936371, 0.4819222688674927, 0.47853565216064453, 0.4746447801589966, 0.4694042503833771, 0.46779122948646545, 0.46632301807403564, 0.45367276668548584, 0.45209774374961853, 0.4552036225795746, 0.441885769367218, 0.38239407539367676, 0.3582274615764618, 0.3514750599861145, 0.34381812810897827, 0.3371503949165344, 0.3315547704696655, 0.3263457119464874, 0.3239271640777588, 0.32037413120269775, 0.31913232803344727, 0.3137155771255493, 0.30990058183670044, 0.30717551708221436, 0.3105558753013611, 0.29942435026168823], 'val_categorical_accuracy': [0.49800100922584534, 0.5432283878326416, 0.5545976758003235, 0.5563468337059021, 0.56209397315979, 0.5567216277122498, 0.5590954422950745, 0.5630934238433838, 0.5640929341316223, 0.568965494632721, 0.5642178654670715, 0.5698400735855103, 0.5789605379104614, 0.5738380551338196, 0.5937031507492065, 0.587581217288971, 0.5964517593383789, 0.6030734777450562, 0.5925787091255188, 0.6121938824653625, 0.6199400424957275, 0.617691159248352, 0.625312328338623, 0.6329335570335388, 0.6445527076721191, 0.6426786780357361, 0.6641679406166077, 0.678 ...

# %% [markdown]
# ##### Shock system with high LR

# %%
LR2 = 4.0e-4

current_optimizer = image2text.optimizer

current_optimizer.learning_rate.assign(LR2)
#image2text.compile(
#        loss='categorical_crossentropy', optimizer=Adam(learning_rate=learning_rate), metrics=['categorical_accuracy']
#    )
early_stopper = tf.keras.callbacks.EarlyStopping(
    monitor = "val_loss", #'val_categorical_accuracy', mode = 'max',
    patience=40,
    restore_best_weights=True
)

lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor= "val_loss",#'val_categorical_accuracy', mode = 'max',
    factor=0.5,
    patience=20,
    min_lr=1e-6,
    verbose=1
)

history2 = image2text.fit(x=[X_train, y_train_in], y=y_train_target,
               epochs = 120,
               batch_size = 32,
               validation_data = ([X_val, y_val_in], y_val_target),
               callbacks=[lr_scheduler, early_stopper])
# Out:
# Epoch 1/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.6575 - loss: 1.1089 - val_categorical_accuracy: 0.5966 - val_loss: 1.3394 - learning_rate: 4.0000e-04
# Epoch 2/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.6668 - loss: 1.0786 - val_categorical_accuracy: 0.5958 - val_loss: 1.3495 - learning_rate: 4.0000e-04
# Epoch 3/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.6682 - loss: 1.0754 - val_categorical_accuracy: 0.6032 - val_loss: 1.3165 - learning_rate: 4.0000e-04
# Epoch 4/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.6726 - loss: 1.0591 - val_categorical_accuracy: 0.6054 - val_loss: 1.2880 - learning_rate: 4.0000e-04
# Epoch 5/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.6781 - loss: 1.0503 - val_categorical_accuracy: 0.6052 - val_loss: 1.2952 - learning_rate: 4.0000e-04
# Epoch 6/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.6793 - loss: 1.0509 - val_categorical_accuracy: 0.6102 - val_loss: 1.3068 - learning_rate: 4.0000e-04
# Epoch 7/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.6857 - loss: 1.0349 - val_categorical_accuracy: 0.6098 - val_loss: 1.2945 - learning_rate: 4.0000e-04
# Epoch 8/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.6913 - loss: 1.0254 - val_categorical_accuracy: 0.6148 - val_loss: 1.2778 - learning_rate: 4.0000e-04
# Epoch 9/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.6938 - loss: 1.0186 - val_categorical_accuracy: 0.6162 - val_loss: 1.3004 - learning_rate: 4.0000e-04
# Epoch 10/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.6984 - loss: 1.0094 - val_categorical_accuracy: 0.6103 - val_loss: 1.3175 - learning_rate: 4.0000e-04
# Epoch 11/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7050 - loss: 0.9982 - val_categorical_accuracy: 0.6336 - val_loss: 1.2893 - learning_rate: 4.0000e-04
# Epoch 12/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7093 - loss: 0.9879 - val_categorical_accuracy: 0.6219 - val_loss: 1.3330 - learning_rate: 4.0000e-04
# Epoch 13/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7133 - loss: 0.9767 - val_categorical_accuracy: 0.6249 - val_loss: 1.2983 - learning_rate: 4.0000e-04
# Epoch 14/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7192 - loss: 0.9652 - val_categorical_accuracy: 0.6293 - val_loss: 1.2965 - learning_rate: 4.0000e-04
# Epoch 15/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7239 - loss: 0.9525 - val_categorical_accuracy: 0.6332 - val_loss: 1.2767 - learning_rate: 4.0000e-04
# Epoch 16/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7322 - loss: 0.9330 - val_categorical_accuracy: 0.6418 - val_loss: 1.2544 - learning_rate: 4.0000e-04
# Epoch 17/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 42ms/step - categorical_accuracy: 0.7363 - loss: 0.9268 - val_categorical_accuracy: 0.6406 - val_loss: 1.2783 - learning_rate: 4.0000e-04
# Epoch 18/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7405 - loss: 0.9157 - val_categorical_accuracy: 0.6522 - val_loss: 1.2244 - learning_rate: 4.0000e-04
# Epoch 19/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7448 - loss: 0.9042 - val_categorical_accuracy: 0.6457 - val_loss: 1.2294 - learning_rate: 4.0000e-04
# Epoch 20/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7508 - loss: 0.8918 - val_categorical_accuracy: 0.6565 - val_loss: 1.2390 - learning_rate: 4.0000e-04
# Epoch 21/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7557 - loss: 0.8819 - val_categorical_accuracy: 0.6539 - val_loss: 1.2502 - learning_rate: 4.0000e-04
# Epoch 22/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7562 - loss: 0.8750 - val_categorical_accuracy: 0.6580 - val_loss: 1.2509 - learning_rate: 4.0000e-04
# Epoch 23/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7620 - loss: 0.8605 - val_categorical_accuracy: 0.6559 - val_loss: 1.2580 - learning_rate: 4.0000e-04
# Epoch 24/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7675 - loss: 0.8471 - val_categorical_accuracy: 0.6605 - val_loss: 1.2412 - learning_rate: 4.0000e-04
# Epoch 25/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7676 - loss: 0.8452 - val_categorical_accuracy: 0.6574 - val_loss: 1.2709 - learning_rate: 4.0000e-04
# Epoch 26/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7712 - loss: 0.8382 - val_categorical_accuracy: 0.6635 - val_loss: 1.2229 - learning_rate: 4.0000e-04
# Epoch 27/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7745 - loss: 0.8274 - val_categorical_accuracy: 0.6625 - val_loss: 1.2325 - learning_rate: 4.0000e-04
# Epoch 28/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7781 - loss: 0.8217 - val_categorical_accuracy: 0.6579 - val_loss: 1.2686 - learning_rate: 4.0000e-04
# Epoch 29/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7816 - loss: 0.8148 - val_categorical_accuracy: 0.6349 - val_loss: 1.3630 - learning_rate: 4.0000e-04
# Epoch 30/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7846 - loss: 0.8074 - val_categorical_accuracy: 0.6660 - val_loss: 1.2294 - learning_rate: 4.0000e-04
# Epoch 31/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7882 - loss: 0.7946 - val_categorical_accuracy: 0.6802 - val_loss: 1.1710 - learning_rate: 4.0000e-04
# Epoch 32/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7880 - loss: 0.7995 - val_categorical_accuracy: 0.6739 - val_loss: 1.1854 - learning_rate: 4.0000e-04
# Epoch 33/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7926 - loss: 0.7852 - val_categorical_accuracy: 0.6707 - val_loss: 1.2142 - learning_rate: 4.0000e-04
# Epoch 34/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7943 - loss: 0.7804 - val_categorical_accuracy: 0.6740 - val_loss: 1.2139 - learning_rate: 4.0000e-04
# Epoch 35/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.7966 - loss: 0.7763 - val_categorical_accuracy: 0.6747 - val_loss: 1.2495 - learning_rate: 4.0000e-04
# Epoch 36/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8001 - loss: 0.7706 - val_categorical_accuracy: 0.6714 - val_loss: 1.2225 - learning_rate: 4.0000e-04
# Epoch 37/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8001 - loss: 0.7654 - val_categorical_accuracy: 0.6815 - val_loss: 1.2091 - learning_rate: 4.0000e-04
# Epoch 38/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8031 - loss: 0.7604 - val_categorical_accuracy: 0.6838 - val_loss: 1.1821 - learning_rate: 4.0000e-04
# Epoch 39/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8057 - loss: 0.7536 - val_categorical_accuracy: 0.6728 - val_loss: 1.2406 - learning_rate: 4.0000e-04
# Epoch 40/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8073 - loss: 0.7540 - val_categorical_accuracy: 0.6537 - val_loss: 1.3141 - learning_rate: 4.0000e-04
# Epoch 41/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8080 - loss: 0.7465 - val_categorical_accuracy: 0.6787 - val_loss: 1.2054 - learning_rate: 4.0000e-04
# Epoch 42/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8111 - loss: 0.7431 - val_categorical_accuracy: 0.6887 - val_loss: 1.1894 - learning_rate: 4.0000e-04
# Epoch 43/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8126 - loss: 0.7368 - val_categorical_accuracy: 0.6889 - val_loss: 1.1805 - learning_rate: 4.0000e-04
# Epoch 44/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8145 - loss: 0.7251 - val_categorical_accuracy: 0.6790 - val_loss: 1.2024 - learning_rate: 4.0000e-04
# Epoch 45/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8171 - loss: 0.7229 - val_categorical_accuracy: 0.6722 - val_loss: 1.2627 - learning_rate: 4.0000e-04
# Epoch 46/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8172 - loss: 0.7215 - val_categorical_accuracy: 0.6970 - val_loss: 1.1516 - learning_rate: 4.0000e-04
# Epoch 47/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8191 - loss: 0.7211 - val_categorical_accuracy: 0.6740 - val_loss: 1.2512 - learning_rate: 4.0000e-04
# Epoch 48/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8215 - loss: 0.7170 - val_categorical_accuracy: 0.6977 - val_loss: 1.1610 - learning_rate: 4.0000e-04
# Epoch 49/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8245 - loss: 0.7069 - val_categorical_accuracy: 0.6720 - val_loss: 1.2891 - learning_rate: 4.0000e-04
# Epoch 50/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8242 - loss: 0.7063 - val_categorical_accuracy: 0.6760 - val_loss: 1.2479 - learning_rate: 4.0000e-04
# Epoch 51/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8268 - loss: 0.7022 - val_categorical_accuracy: 0.6837 - val_loss: 1.2221 - learning_rate: 4.0000e-04
# Epoch 52/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8261 - loss: 0.7034 - val_categorical_accuracy: 0.6848 - val_loss: 1.2011 - learning_rate: 4.0000e-04
# Epoch 53/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8275 - loss: 0.6975 - val_categorical_accuracy: 0.6760 - val_loss: 1.2543 - learning_rate: 4.0000e-04
# Epoch 54/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8332 - loss: 0.6887 - val_categorical_accuracy: 0.6808 - val_loss: 1.2322 - learning_rate: 4.0000e-04
# Epoch 55/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8325 - loss: 0.6856 - val_categorical_accuracy: 0.6772 - val_loss: 1.2737 - learning_rate: 4.0000e-04
# Epoch 56/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8325 - loss: 0.6856 - val_categorical_accuracy: 0.6908 - val_loss: 1.2038 - learning_rate: 4.0000e-04
# Epoch 57/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8327 - loss: 0.6836 - val_categorical_accuracy: 0.6835 - val_loss: 1.2182 - learning_rate: 4.0000e-04
# Epoch 58/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8335 - loss: 0.6829 - val_categorical_accuracy: 0.6970 - val_loss: 1.1630 - learning_rate: 4.0000e-04
# Epoch 59/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8375 - loss: 0.6729 - val_categorical_accuracy: 0.7089 - val_loss: 1.1294 - learning_rate: 4.0000e-04
# Epoch 60/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8398 - loss: 0.6717 - val_categorical_accuracy: 0.6904 - val_loss: 1.1995 - learning_rate: 4.0000e-04
# Epoch 61/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8386 - loss: 0.6707 - val_categorical_accuracy: 0.6800 - val_loss: 1.2493 - learning_rate: 4.0000e-04
# Epoch 62/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8407 - loss: 0.6642 - val_categorical_accuracy: 0.6983 - val_loss: 1.1809 - learning_rate: 4.0000e-04
# Epoch 63/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8433 - loss: 0.6600 - val_categorical_accuracy: 0.6867 - val_loss: 1.2630 - learning_rate: 4.0000e-04
# Epoch 64/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8432 - loss: 0.6612 - val_categorical_accuracy: 0.7019 - val_loss: 1.1690 - learning_rate: 4.0000e-04
# Epoch 65/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8426 - loss: 0.6591 - val_categorical_accuracy: 0.6962 - val_loss: 1.2270 - learning_rate: 4.0000e-04
# Epoch 66/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8433 - loss: 0.6564 - val_categorical_accuracy: 0.6843 - val_loss: 1.2470 - learning_rate: 4.0000e-04
# Epoch 67/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8467 - loss: 0.6527 - val_categorical_accuracy: 0.6852 - val_loss: 1.2430 - learning_rate: 4.0000e-04
# Epoch 68/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8474 - loss: 0.6499 - val_categorical_accuracy: 0.6893 - val_loss: 1.2358 - learning_rate: 4.0000e-04
# Epoch 69/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8459 - loss: 0.6463 - val_categorical_accuracy: 0.6893 - val_loss: 1.2299 - learning_rate: 4.0000e-04
# Epoch 70/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8500 - loss: 0.6437 - val_categorical_accuracy: 0.6875 - val_loss: 1.2651 - learning_rate: 4.0000e-04
# Epoch 71/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8491 - loss: 0.6423 - val_categorical_accuracy: 0.6828 - val_loss: 1.2880 - learning_rate: 4.0000e-04
# Epoch 72/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8487 - loss: 0.6451 - val_categorical_accuracy: 0.6975 - val_loss: 1.2057 - learning_rate: 4.0000e-04
# Epoch 73/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8508 - loss: 0.6376 - val_categorical_accuracy: 0.6790 - val_loss: 1.2770 - learning_rate: 4.0000e-04
# Epoch 74/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8501 - loss: 0.6425 - val_categorical_accuracy: 0.7009 - val_loss: 1.1793 - learning_rate: 4.0000e-04
# Epoch 75/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8516 - loss: 0.6365 - val_categorical_accuracy: 0.6883 - val_loss: 1.2662 - learning_rate: 4.0000e-04
# Epoch 76/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8525 - loss: 0.6327 - val_categorical_accuracy: 0.6815 - val_loss: 1.2704 - learning_rate: 4.0000e-04
# Epoch 77/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8543 - loss: 0.6291 - val_categorical_accuracy: 0.6897 - val_loss: 1.2594 - learning_rate: 4.0000e-04
# Epoch 78/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8541 - loss: 0.6313 - val_categorical_accuracy: 0.6894 - val_loss: 1.2185 - learning_rate: 4.0000e-04
# Epoch 79/120
# 499/500 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.8589 - loss: 0.6132
# Epoch 79: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8546 - loss: 0.6257 - val_categorical_accuracy: 0.7029 - val_loss: 1.1831 - learning_rate: 4.0000e-04
# Epoch 80/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8774 - loss: 0.5582 - val_categorical_accuracy: 0.6989 - val_loss: 1.2385 - learning_rate: 2.0000e-04
# Epoch 81/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8833 - loss: 0.5320 - val_categorical_accuracy: 0.7025 - val_loss: 1.2152 - learning_rate: 2.0000e-04
# Epoch 82/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8841 - loss: 0.5215 - val_categorical_accuracy: 0.6902 - val_loss: 1.2849 - learning_rate: 2.0000e-04
# Epoch 83/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8877 - loss: 0.5152 - val_categorical_accuracy: 0.6912 - val_loss: 1.2951 - learning_rate: 2.0000e-04
# Epoch 84/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8885 - loss: 0.5094 - val_categorical_accuracy: 0.6868 - val_loss: 1.3231 - learning_rate: 2.0000e-04
# Epoch 85/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8919 - loss: 0.4992 - val_categorical_accuracy: 0.6933 - val_loss: 1.3072 - learning_rate: 2.0000e-04
# Epoch 86/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8905 - loss: 0.4984 - val_categorical_accuracy: 0.6950 - val_loss: 1.3063 - learning_rate: 2.0000e-04
# Epoch 87/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8942 - loss: 0.4895 - val_categorical_accuracy: 0.6977 - val_loss: 1.2674 - learning_rate: 2.0000e-04
# Epoch 88/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8942 - loss: 0.4865 - val_categorical_accuracy: 0.6902 - val_loss: 1.3352 - learning_rate: 2.0000e-04
# Epoch 89/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8938 - loss: 0.4871 - val_categorical_accuracy: 0.6938 - val_loss: 1.3134 - learning_rate: 2.0000e-04
# Epoch 90/120
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - categorical_accuracy: 0.8948 - loss: 0.4833 - val_categorical_accuracy: 0.6968 - val_loss: 1.2938 - learning_rate: 2.0000e-04
# Epoch 91/120
#  31/500 ━━━━━━━━━━━━━━━━━━━━ 19s 41ms/step - categorical_accuracy: 0.9047 - loss: 0.4644
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 23
#       9 early_stopper = tf.keras.callbacks.EarlyStopping(
#      10     monitor = "val_loss", #'val_categorical_accuracy', mode = 'max',
#      11     patience=40,
#      12     restore_best_weights=True
#      13 )
#      15 lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
#      16     monitor= "val_loss",#'val_categorical_accuracy', mode = 'max',
#      17     factor=0.5,
#    (...)     20     verbose=1
#      21 )
# ---> 23 history2 = image2text.fit(x=[X_train, y_train_in], y=y_train_target,
#      24                epochs = 120,
#      25                batch_size = 32,
#      26                validation_data = ([X_val, y_val_in], y_val_target),
#      27                callbacks=[lr_scheduler, early_stopper])
#
# File ~/.conda/envs/IDL/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.conda/envs/IDL/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:399, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397 for begin_step, end_step, iterator in epoch_iterator:
#     398     callbacks.on_train_batch_begin(begin_step)
# --> 399     logs = self.train_function(iterator)
#     400     callbacks.on_train_batch_end(end_step, logs)
#     401     if self.stop_training:
#
# File ~/.conda/envs/IDL/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:241, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     237 def function(iterator):
#     238     if isinstance(
#     239         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240     ):
# --> 241         opt_outputs = multi_step_on_iterator(iterator)
#     242         if not opt_outputs.has_value():
#     243             raise StopIteration
#
# File ~/.conda/envs/IDL/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.conda/envs/IDL/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/.conda/envs/IDL/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/.conda/envs/IDL/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/.conda/envs/IDL/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/.conda/envs/IDL/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/.conda/envs/IDL/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/.conda/envs/IDL/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File ~/.conda/envs/IDL/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ##### Inference loop

# %%
def Encoder_inference(trained_model_full):
        
    X_in = tf.keras.Input(shape=(5, 28, 28, 1))

    encoder_outputs = trained_model_full.get_layer("encoder_model")
    Sequence, hidden, cell= encoder_outputs(X_in)

    h_initial = trained_model_full.get_layer('h0')(tf.keras.layers.Flatten()(hidden))
    c_initial = trained_model_full.get_layer('c0')(tf.keras.layers.Flatten()(cell))

    keys_flat = TimeDistributed(Flatten())(Sequence)
    keys_decoder = trained_model_full.get_layer('key_decoder')
    keys = keys_decoder(keys_flat)


    encoder_inference = tf.keras.Model(inputs=X_in, outputs=[keys, h_initial, c_initial], name="encoder_inference")
    return encoder_inference


def Decoder_inference(trained_full_model, max_size, vocab_size=len(vocabulary_tf)):
    
    # Input objects
    input_token = Input(shape=(1, vocab_size), name='token_input')
    keys = Input(shape=(None, max_size), name='keys')
    input_h = Input(shape=(max_size,), name='input_h')
    input_c = Input(shape=(max_size,), name='input_c')

    # Here we pull all the trained layers from the model
    lstm = trained_full_model.get_layer('decoder_lstm')
    attention = trained_full_model.get_layer('attention_block')
    lstm.return_sequences = True # for some reason this is necessary
    lstm.return_state = True
    concat = trained_full_model.get_layer('concat_q_A')
    combined_dense = trained_full_model.get_layer('combined_dense')
    res_dense = trained_full_model.get_layer('decoder_res_dense')
    add_res = trained_full_model.get_layer('decoder_with_residual')
    layernorm = trained_full_model.get_layer('decoder_layer_norm')
    final_dense = trained_full_model.get_layer('decoder_dense')
    
    # 
    Query, h, c = lstm(
        input_token, 
        initial_state=[input_h, input_c]
    )

    attention_values = attention([Query, keys])
    combined_attention_output = concat([Query, attention_values])
    mixed_features = combined_dense(combined_attention_output)

    # apply residual connection
    residual = res_dense(input_token)
    residual_added = add_res([mixed_features, residual])

    layernorm_final = layernorm(residual_added)
    prediction = final_dense(layernorm_final)

    decoder_inference_model = tf.keras.Model(
        inputs=[input_token, keys, input_h, input_c],
        outputs=[prediction, h, c],
    )
    
    return decoder_inference_model

# %%
encoder_inference = Encoder_inference(
    image2text
)

decoder_inference = Decoder_inference(
    image2text, max_size=max_size
)

# %%
from tensorflow.keras.utils import to_categorical

def generate_prediction_sequence(
    X_sample, 
    encoder_inference_model, 
    decoder_inference_model, 
    max_answer_length_tf, 
    indices, 
    reverse_indices, 
    vocab_size,
):
    keys, h_initial, c_initial = encoder_inference_model.predict(X_sample, verbose=0)
    states = [h_initial, c_initial]
    start_token = indices['<start>']
    input_token = to_categorical(start_token, num_classes=vocab_size).reshape(1, 1, vocab_size)
    predicted_indices = []

    for t in range(max_answer_length_tf):
        decoder_input = [input_token, keys] + states
        predictions_output = decoder_inference_model.predict(decoder_input, verbose=0)
        predictions = predictions_output[0]
        h = predictions_output[1]
        c = predictions_output[2]
        predicted_index = np.argmax(predictions[0, -1, :])
        predicted_indices.append(predicted_index)
        if predicted_index == indices['<end>']:
            break
        
        states = [h, c]
        input_token = to_categorical(predicted_index, num_classes=vocab_size).reshape(1, 1, vocab_size)

    string = "".join([
        reverse_indices[p]
        for p in predicted_indices
        if reverse_indices[p] not in ["<start>", "<end>", ' ']
    ])

    return string

# %%
def evaluate_test_set(start, N_samples, printing = False):
    counter_math_correctness = 0
    counter_token_correctness = 0
    for sample in range(start, start+N_samples):
        X_sample = X_test[sample]
        X_sample_reshaped = np.expand_dims(X_sample, axis=-1)
        X_sample_reshaped2 = np.expand_dims(X_sample_reshaped, axis=0)
        max_answer_length_tf=4
        vocab_size = len(vocabulary_tf)

        sequence = generate_prediction_sequence(
            X_sample_reshaped2, 
            encoder_inference, 
            decoder_inference, 
            max_answer_length_tf, 
            indices, 
            reverse_indices, 
            vocab_size,    
        )

        ground_truth_index = np.argmax(y_test_target[sample],axis=-1)
        ground_truth_string = "".join([reverse_indices[index] for index in ground_truth_index
                                        if reverse_indices[index] not in ["<start>", "<end>", ' ']])

        if printing== True:
            print(f"Actual string = {ground_truth_string}. Predicted string = {sequence}")

        if ground_truth_string == sequence:
            counter_math_correctness +=1
        
        for token in range(min(len(ground_truth_string), len(sequence))):
            if ground_truth_string[token]==sequence[token]:
                counter_token_correctness+=1
        
        print(f"step {sample-start} out of {N_samples}")
    
    math_accuracy = counter_math_correctness/N_samples
    token_accuracy = counter_token_correctness/(3*N_samples)

    print(f"math accuracy = {math_accuracy}. token accuracy = {token_accuracy}")

    return math_accuracy, token_accuracy

# %%
def evaluate_test_set2(X_samples, printing = False):
    counter_math_correctness = 0
    counter_token_correctness = 0
    N_samples=len(X_samples)
    for sample in range(N_samples):
        X_sample = X_samples[sample]
        X_sample_reshaped = np.expand_dims(X_sample, axis=-1)
        X_sample_reshaped2 = np.expand_dims(X_sample_reshaped, axis=0)
        max_answer_length_tf=4
        vocab_size = len(vocabulary_tf)

        sequence = generate_prediction_sequence(
            X_sample_reshaped2, 
            encoder_inference, 
            decoder_inference, 
            max_answer_length_tf, 
            indices, 
            reverse_indices, 
            vocab_size,    
        )

        ground_truth_index = np.argmax(y_test_target[sample],axis=-1)
        ground_truth_string = "".join([reverse_indices[index] for index in ground_truth_index
                                        if reverse_indices[index] not in ["<start>", "<end>", ' ']])

        if printing== True:
            print(f"Actual string = {ground_truth_string}. Predicted string = {sequence}")

        if ground_truth_string == sequence:
            counter_math_correctness +=1
        
        for token in range(min(len(ground_truth_string), len(sequence))):
            if ground_truth_string[token]==sequence[token]:
                counter_token_correctness+=1
        
        print(f"step {sample} out of {N_samples}")
    
    math_accuracy = counter_math_correctness/N_samples
    token_accuracy = counter_token_correctness/(3*N_samples)

    print(f"math accuracy = {math_accuracy}. token accuracy = {token_accuracy}")

    return math_accuracy, token_accuracy

# %%
start = 200
N_samples = 2
X_sample_set = X_test[start: start+N_samples]
math_accuracy, token_accuracy = evaluate_test_set(start, N_samples, printing=True)
# Out:
# Actual string = 1020030. Predicted string = 1111
# step 0 out of 2
# Actual string = 9080000. Predicted string = 1113
# step 1 out of 2
# math accuracy = 0.0. token accuracy = 0.16666666666666666

# %%
math_accuracy
# Out:
# 0.0
